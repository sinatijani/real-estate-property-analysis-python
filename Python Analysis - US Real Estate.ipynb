# %%
# Checking files in the directory

# !ls
# Out:
# LICENSE
# Power Bi Dashboard US Real Estate Data.pbix
# Python Analysis - US Real Estate.ipynb
# Python Analysis - US Real Estate.pdf
# README.md
# Report - US Real Estate Report Analysis Sina Tijani.pptx
# US Real Estate Data - Business Statistics .pbix
# cleaned_us_real_estate.xlsx
# raw_dataset-USRealEstate.csv
# requirements.txt
# venv
# ~$1 Group 2 Business Statistics (sina_tijani).docx
# ~$Report - US Real Estate Report Analysis Sina Tijani.pptx

# %%
pwd
# Out:
# '/Volumes/AnisX10pro/GitHub/real-estate-property-analysis-python'

# %%
# installing required packages

# !pip install pandas numpy seaborn matplotlib scipy openpyxl
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy in ./venv/lib/python3.13/site-packages (2.2.4)
# Requirement already satisfied: seaborn in ./venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: scipy in ./venv/lib/python3.13/site-packages (1.15.2)
# Requirement already satisfied: openpyxl in ./venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: et-xmlfile in ./venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Importing needed libraries

import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
# Importing the data set

df = pd.read_csv(r'/Volumes/AnisX10pro/GitHub/real-estate-property-analysis-python/raw_dataset-USRealEstate.csv')
df
# Out:
#           status    price   bed  bath  acre_lot  \
# 0       for_sale   105000   3.0   2.0      0.12
# 1       for_sale    80000   4.0   2.0      0.08
# 2       for_sale    67000   2.0   1.0      0.15
# 3       for_sale   145000   4.0   2.0      0.10
# 4       for_sale    65000   6.0   2.0      0.05
# ...          ...      ...   ...   ...       ...
# 613154  for_sale   429000   6.0   3.0      0.12
# 613155  for_sale  1095000   5.0   5.0      0.24
# 613156  for_sale  1500000   6.0   3.0      3.97
# 613157  for_sale   550000  11.0   3.0      0.28
# 613158  for_sale   375000   7.0   5.0       NaN
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...                                                   ...
# 613154           556 Walnut St, Elizabeth City, NJ, 07201
# 613155             386 Page Ave, Staten Island, NY, 10307
# 613156        84 Hillcrest Rd, Bridgewater Twp, NJ, 08836
# 613157             25 Chestnut St, East Orange, NJ, 07018
# 613158               196 Astoria Pl, Union Twp, NJ, 07083
#
#                                                street             city  \
# 0                        Sector Yahuecas Titulo # V84         Adjuntas
# 1                                  Km 78 9 Carr # 135         Adjuntas
# 2                                    556G 556-G 16 St       Juana Diaz
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce            Ponce
# 4                                          14 Navarro         Mayaguez
# ...                                               ...              ...
# 613154                                  556 Walnut St   Elizabeth City
# 613155                                   386 Page Ave    Staten Island
# 613156                                84 Hillcrest Rd  Bridgewater Twp
# 613157                                 25 Chestnut St      East Orange
# 613158                                 196 Astoria Pl        Union Twp
#
#               state  zip_code  house_size  sold_date
# 0       Puerto Rico     601.0       920.0        NaN
# 1       Puerto Rico     601.0      1527.0        NaN
# 2       Puerto Rico     795.0       748.0        NaN
# 3       Puerto Rico     731.0      1800.0        NaN
# 4       Puerto Rico     680.0         NaN        NaN
# ...             ...       ...         ...        ...
# 613154   New Jersey    7201.0         NaN  9/10/2019
# 613155     New York   10307.0      3140.0  6/16/2008
# 613156   New Jersey    8836.0      3994.0        NaN
# 613157   New Jersey    7018.0         NaN   1/7/2019
# 613158   New Jersey    7083.0         NaN   7/9/2003
#
# [613159 rows x 12 columns]

# %% [markdown]
# Inspecting the column headers to make sure they're formatted in the right format for my work style, and they are so won't make any changes.

# %%
# finding perfect duplicates

df[df.duplicated()]
# Out:
#           status    price   bed  bath  acre_lot  \
# 135     for_sale   105000   3.0   2.0      0.08
# 139     for_sale   300000   5.0   3.0      7.46
# 140     for_sale   155000   3.0   2.0      0.10
# 148     for_sale   122500   3.0   2.0      0.05
# 149     for_sale   575000   3.0   2.0      3.88
# ...          ...      ...   ...   ...       ...
# 613153  for_sale   225000   NaN   NaN      4.48
# 613154  for_sale   429000   6.0   3.0      0.12
# 613156  for_sale  1500000   6.0   3.0      3.97
# 613157  for_sale   550000  11.0   3.0      0.28
# 613158  for_sale   375000   7.0   5.0       NaN
#
#                                              full_address  \
# 135                       DD18 Calle 28, Ponce, PR, 00728
# 139     Pr 120 Bo Maravilla Sur K M # 335, Las Marias,...
# 140                                  Pr, Lares, PR, 00669
# 148                   16 Muoz Rivera St, Yauco, PR, 00698
# 149        5.8 Carr 435 Km # 58, San Sebastian, PR, 00685
# ...                                                   ...
# 613153           249 Triangle Rd, Hillsborough, NJ, 08844
# 613154           556 Walnut St, Elizabeth City, NJ, 07201
# 613156        84 Hillcrest Rd, Bridgewater Twp, NJ, 08836
# 613157             25 Chestnut St, East Orange, NJ, 07018
# 613158               196 Astoria Pl, Union Twp, NJ, 07083
#
#                                    street             city        state  \
# 135                         DD18 Calle 28            Ponce  Puerto Rico
# 139     Pr 120 Bo Maravilla Sur K M # 335       Las Marias  Puerto Rico
# 140                                    Pr            Lares  Puerto Rico
# 148                     16 Muoz Rivera St            Yauco  Puerto Rico
# 149                  5.8 Carr 435 Km # 58    San Sebastian  Puerto Rico
# ...                                   ...              ...          ...
# 613153                    249 Triangle Rd     Hillsborough   New Jersey
# 613154                      556 Walnut St   Elizabeth City   New Jersey
# 613156                    84 Hillcrest Rd  Bridgewater Twp   New Jersey
# 613157                     25 Chestnut St      East Orange   New Jersey
# 613158                     196 Astoria Pl        Union Twp   New Jersey
#
#         zip_code  house_size   sold_date
# 135        728.0      1500.0         NaN
# 139        670.0      5403.0         NaN
# 140        669.0      4161.0         NaN
# 148        698.0      1118.0         NaN
# 149        685.0      4000.0         NaN
# ...          ...         ...         ...
# 613153    8844.0         NaN  11/20/2000
# 613154    7201.0         NaN   9/10/2019
# 613156    8836.0      3994.0         NaN
# 613157    7018.0         NaN    1/7/2019
# 613158    7083.0         NaN    7/9/2003
#
# [531788 rows x 12 columns]

# %%
# sorting the perfect duplicates by full address

df[df.duplicated()].sort_values(by='full_address')
# Out:
#           status   price  bed  bath  acre_lot  \
# 220906  for_sale  130000  NaN   NaN      1.48
# 157256  for_sale  130000  NaN   NaN      1.48
# 210382  for_sale  130000  NaN   NaN      1.48
# 167626  for_sale  130000  NaN   NaN      1.48
# 220756  for_sale  130000  NaN   NaN      1.48
# ...          ...     ...  ...   ...       ...
# 10848   for_sale  135000  5.0   2.0      0.09
# 12731   for_sale  135000  5.0   2.0      0.09
# 4091    for_sale  135000  5.0   2.0      0.09
# 3800    for_sale  135000  5.0   2.0      0.09
# 9639    for_sale  135000  5.0   2.0      0.09
#
#                                       full_address                  street  \
# 220906          0 52 Range Ave, Taunton, MA, 02780          0 52 Range Ave
# 157256          0 52 Range Ave, Taunton, MA, 02780          0 52 Range Ave
# 210382          0 52 Range Ave, Taunton, MA, 02780          0 52 Range Ave
# 167626          0 52 Range Ave, Taunton, MA, 02780          0 52 Range Ave
# 220756          0 52 Range Ave, Taunton, MA, 02780          0 52 Range Ave
# ...                                            ...                     ...
# 10848   Zorzal 84 Bo Cuchillas, Morovis, PR, 00687  Zorzal 84 Bo Cuchillas
# 12731   Zorzal 84 Bo Cuchillas, Morovis, PR, 00687  Zorzal 84 Bo Cuchillas
# 4091    Zorzal 84 Bo Cuchillas, Morovis, PR, 00687  Zorzal 84 Bo Cuchillas
# 3800    Zorzal 84 Bo Cuchillas, Morovis, PR, 00687  Zorzal 84 Bo Cuchillas
# 9639    Zorzal 84 Bo Cuchillas, Morovis, PR, 00687  Zorzal 84 Bo Cuchillas
#
#            city          state  zip_code  house_size sold_date
# 220906  Taunton  Massachusetts    2780.0         NaN       NaN
# 157256  Taunton  Massachusetts    2780.0         NaN       NaN
# 210382  Taunton  Massachusetts    2780.0         NaN       NaN
# 167626  Taunton  Massachusetts    2780.0         NaN       NaN
# 220756  Taunton  Massachusetts    2780.0         NaN       NaN
# ...         ...            ...       ...         ...       ...
# 10848   Morovis    Puerto Rico     687.0      1414.0       NaN
# 12731   Morovis    Puerto Rico     687.0      1414.0       NaN
# 4091    Morovis    Puerto Rico     687.0      1414.0       NaN
# 3800    Morovis    Puerto Rico     687.0      1414.0       NaN
# 9639    Morovis    Puerto Rico     687.0      1414.0       NaN
#
# [531788 rows x 12 columns]

# %%
# finding what percent of the dataset are duplicates

duplicate_percent = len(df[df.duplicated()])/len(df)*100

print(f'The dataset has {duplicate_percent:.2f}% perfect duplicate entries that has to be removed')
# Out:
# The dataset has 86.73% perfect duplicate entries that has to be removed

# %% [markdown]
# Cross checking the columns before removing the duplicates. I find that the column full_address is what is broken down into the 4 columns street, city, state and zip_code. City and state will be maintained but street and zip_code are not necessary for the analysis I will do. So those have to be dropped too.

# %%
# removing the duplciates and dropping the street and zip_code columns. Then store this result in a different dataframe.

df2 = df.drop_duplicates().drop(columns=['street', 'zip_code']).reset_index(drop=True)
df2
# Out:
#          status    price  bed  bath  acre_lot  \
# 0      for_sale   105000  3.0   2.0      0.12
# 1      for_sale    80000  4.0   2.0      0.08
# 2      for_sale    67000  2.0   1.0      0.15
# 3      for_sale   145000  4.0   2.0      0.10
# 4      for_sale    65000  6.0   2.0      0.05
# ...         ...      ...  ...   ...       ...
# 81366  for_sale   179900  2.0   2.0       NaN
# 81367  for_sale   235000  2.0   2.0      0.14
# 81368  for_sale   220000  NaN   NaN      5.68
# 81369  for_sale    50000  NaN   NaN      0.18
# 81370  for_sale  1095000  5.0   5.0      0.24
#
#                                             full_address            city  \
# 0      Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601        Adjuntas
# 1                Km 78 9 Carr # 135, Adjuntas, PR, 00601        Adjuntas
# 2                556G 556-G 16 St, Juana Diaz, PR, 00795      Juana Diaz
# 3      R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...           Ponce
# 4                        14 Navarro, Mayaguez, PR, 00680        Mayaguez
# ...                                                  ...             ...
# 81366  265 Spotswood Dr Unit 88-265, Spotswood, NJ, 0...       Spotswood
# 81367  1101 Stoneridge Cir Unit 1101, Helmetta, NJ, 0...        Helmetta
# 81368        95 Readington Rd, Readington Twp, NJ, 08889  Readington Twp
# 81369                 Brooklyn Ave, Spotswood, NJ, 08884       Spotswood
# 81370             386 Page Ave, Staten Island, NY, 10307   Staten Island
#
#              state  house_size  sold_date
# 0      Puerto Rico       920.0        NaN
# 1      Puerto Rico      1527.0        NaN
# 2      Puerto Rico       748.0        NaN
# 3      Puerto Rico      1800.0        NaN
# 4      Puerto Rico         NaN        NaN
# ...            ...         ...        ...
# 81366   New Jersey         NaN        NaN
# 81367   New Jersey      1198.0   4/3/2007
# 81368   New Jersey         NaN        NaN
# 81369   New Jersey         NaN        NaN
# 81370     New York      3140.0  6/16/2008
#
# [81371 rows x 10 columns]

# %%
# checking the results

df2.sort_values(by='full_address')
# Out:
#          status    price  bed  bath  acre_lot  \
# 23297  for_sale  1250000  NaN   NaN     32.30
# 19249  for_sale   130000  NaN   NaN      1.48
# 22102  for_sale   120000  NaN   NaN      2.61
# 23184  for_sale   950000  4.0   3.0      0.47
# 23185  for_sale  1150000  4.0   3.0      0.47
# ...         ...      ...  ...   ...       ...
# 18842  for_sale  1850000  5.0   4.0      1.59
# 16815  for_sale  2150000  2.0   3.0       NaN
# 3268   for_sale    95000  3.0   3.0      0.06
# 32275  for_sale   150000  NaN   NaN     50.00
# 774    for_sale   135000  5.0   2.0      0.09
#
#                                             full_address                city  \
# 23297  0 0 Bay St /Judson St /Church St, Tiverton, RI...            Tiverton
# 19249                 0 52 Range Ave, Taunton, MA, 02780             Taunton
# 22102                 0 53 Range Ave, Taunton, MA, 02780             Taunton
# 23184           0 A1 Morrison Ave, Middletown, RI, 02842          Middletown
# 23185           0 A3 Morrison Ave, Middletown, RI, 02842          Middletown
# ...                                                  ...                 ...
# 18842      Zero Bridge St Lot Eight, Hamilton, MA, 01982            Hamilton
# 16815      Zero Worcester Sq Unit TH1, Boston, MA, 02118              Boston
# 3268   Zh-11 Calle 31 Urb Riverview # 501-826608, Bay...             Bayamon
# 32275             Zorn Dr, Middletown Springs, VT, 05757  Middletown Springs
# 774           Zorzal 84 Bo Cuchillas, Morovis, PR, 00687             Morovis
#
#                state  house_size sold_date
# 23297   Rhode Island         NaN       NaN
# 19249  Massachusetts         NaN       NaN
# 22102  Massachusetts         NaN       NaN
# 23184   Rhode Island      2500.0       NaN
# 23185   Rhode Island      3120.0       NaN
# ...              ...         ...       ...
# 18842  Massachusetts      4800.0       NaN
# 16815  Massachusetts      1514.0       NaN
# 3268     Puerto Rico       752.0       NaN
# 32275        Vermont         NaN       NaN
# 774      Puerto Rico      1414.0       NaN
#
# [81371 rows x 10 columns]

# %%
# checking for the number of missing values across columns 

df2.isnull().sum()
# Out:
# status              0
# price               0
# bed             14034
# bath            12744
# acre_lot        21737
# full_address        0
# city               21
# state               0
# house_size      27628
# sold_date       42491
# dtype: int64

# %% [markdown]
# With a total row count of 81,371, having 42,491 sold_date values missing which looks almost 50% would prompt concern to drop that. But since this is real estate data, no sold_date is assumed that the property has not been sold yet which is good information. Also with lesser percentag of values missing in other columns, I would decide to keep the sold_date column as some analysis can be performed with and without it.
#
# That being said, for_sale and ready_to_build are values seen under status column. Have to confirm if there are "sold" entries to signifiy a property sold. if not, then we assume no sold_date means not sold.

# %%
# confirming if a sold property will be shown as sold under status by checking for unique variables

df2.status.unique()
# Out:
# array(['for_sale', 'ready_to_build'], dtype=object)

# %% [markdown]
# Since that showed there no no "sold" value in the column, then we maintain the initial assumption. No sold date means property is not sold.

# %% [markdown]
# While perfect duplicates across all columns are removed, I'm now curious if there are duplicates in full_adress since that seems to be the unique identifier for each address. This is also with the assumption that, each house or property is unique and therefore should have a single full_address.

# %%
# finding ALL duplicates in full address by using keep=True. sorting them by full_address

df2[df2.full_address.duplicated()].sort_values(by='full_address').head(20)
# Out:
#                status    price  bed  bath  acre_lot  \
# 23388        for_sale   399999  3.0   2.0      0.12
# 23251        for_sale  1250000  4.0   4.0      0.17
# 23224        for_sale  1200000  NaN   NaN      0.25
# 22019        for_sale   799000  NaN   NaN      1.07
# 23257        for_sale   779500  4.0   3.0      0.69
# 39572  ready_to_build   831995  3.0   NaN       NaN
# 39571  ready_to_build   842995  3.0   NaN       NaN
# 39568  ready_to_build   796995  2.0   NaN       NaN
# 69279  ready_to_build   970995  3.0   NaN       NaN
# 69280  ready_to_build  1038995  3.0   NaN       NaN
# 162          for_sale   290000  NaN   NaN     16.22
# 28453        for_sale  1200000  NaN   NaN    165.00
# 17472  ready_to_build  1689995  4.0   NaN       NaN
# 17473  ready_to_build  1635995  4.0   NaN       NaN
# 17471  ready_to_build  1699995  4.0   NaN       NaN
# 22530        for_sale   899000  2.0   1.0       NaN
# 60553        for_sale   619000  3.0   1.0       NaN
# 79185  ready_to_build   489990  2.0   NaN       NaN
# 60549        for_sale   549000  6.0   3.0      0.06
# 71006        for_sale  1157000  1.0   1.0       NaN
#
#                                             full_address                city  \
# 23388                   0 Erie St, Woonsocket, RI, 02895          Woonsocket
# 23251          0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 23224          0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 22019               0 Rumstick Rd, Barrington, RI, 02806          Barrington
# 23257                  0 Whitman Way, Lincoln, RI, 02865             Lincoln
# 39572                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 39571                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 39568                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 69279           1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 69280           1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 162                           1 Pr, Cabo Rojo, PR, 00623           Cabo Rojo
# 28453                 10 Gables End, Belgrade, ME, 04917            Belgrade
# 17472                10 Stillwater Rd, Canton, MA, 02021              Canton
# 17473                10 Stillwater Rd, Canton, MA, 02021              Canton
# 17471                10 Stillwater Rd, Canton, MA, 02021              Canton
# 22530                100 Deforest Rd, Montauk, NY, 11954             Montauk
# 60553  100 Overlook Ter Apt 312, New York City, NY, 1...       New York City
# 79185  100 S Washington Avenue, Dunellen Borough, NJ,...    Dunellen Borough
# 60549                  100 W 12th St, Bayonne, NJ, 07002             Bayonne
# 71006         100 W 93rd St Apt 14B, New York, NY, 10025            New York
#
#                state  house_size  sold_date
# 23388   Rhode Island      1250.0        NaN
# 23251   Rhode Island      3108.0        NaN
# 23224   Rhode Island         NaN        NaN
# 22019   Rhode Island         NaN        NaN
# 23257   Rhode Island      3000.0        NaN
# 39572    Connecticut      2500.0        NaN
# 39571    Connecticut      2721.0        NaN
# 39568    Connecticut      1953.0        NaN
# 69279     New Jersey      3060.0        NaN
# 69280     New Jersey      3020.0        NaN
# 162      Puerto Rico         NaN        NaN
# 28453          Maine         NaN        NaN
# 17472  Massachusetts      4172.0        NaN
# 17473  Massachusetts      3605.0        NaN
# 17471  Massachusetts      4053.0        NaN
# 22530       New York       590.0        NaN
# 60553       New York         NaN        NaN
# 79185     New Jersey      1629.0        NaN
# 60549     New Jersey         NaN   4/5/2003
# 71006       New York       739.0  11/2/2017

# %%
# saving this duplicate should it be needed later on

full_address_duplicates = df2[df2.full_address.duplicated()].sort_values(by='full_address')
full_address_duplicates.head(20)
# Out:
#                status    price  bed  bath  acre_lot  \
# 23388        for_sale   399999  3.0   2.0      0.12
# 23251        for_sale  1250000  4.0   4.0      0.17
# 23224        for_sale  1200000  NaN   NaN      0.25
# 22019        for_sale   799000  NaN   NaN      1.07
# 23257        for_sale   779500  4.0   3.0      0.69
# 39572  ready_to_build   831995  3.0   NaN       NaN
# 39571  ready_to_build   842995  3.0   NaN       NaN
# 39568  ready_to_build   796995  2.0   NaN       NaN
# 69279  ready_to_build   970995  3.0   NaN       NaN
# 69280  ready_to_build  1038995  3.0   NaN       NaN
# 162          for_sale   290000  NaN   NaN     16.22
# 28453        for_sale  1200000  NaN   NaN    165.00
# 17472  ready_to_build  1689995  4.0   NaN       NaN
# 17473  ready_to_build  1635995  4.0   NaN       NaN
# 17471  ready_to_build  1699995  4.0   NaN       NaN
# 22530        for_sale   899000  2.0   1.0       NaN
# 60553        for_sale   619000  3.0   1.0       NaN
# 79185  ready_to_build   489990  2.0   NaN       NaN
# 60549        for_sale   549000  6.0   3.0      0.06
# 71006        for_sale  1157000  1.0   1.0       NaN
#
#                                             full_address                city  \
# 23388                   0 Erie St, Woonsocket, RI, 02895          Woonsocket
# 23251          0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 23224          0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 22019               0 Rumstick Rd, Barrington, RI, 02806          Barrington
# 23257                  0 Whitman Way, Lincoln, RI, 02865             Lincoln
# 39572                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 39571                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 39568                  1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 69279           1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 69280           1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 162                           1 Pr, Cabo Rojo, PR, 00623           Cabo Rojo
# 28453                 10 Gables End, Belgrade, ME, 04917            Belgrade
# 17472                10 Stillwater Rd, Canton, MA, 02021              Canton
# 17473                10 Stillwater Rd, Canton, MA, 02021              Canton
# 17471                10 Stillwater Rd, Canton, MA, 02021              Canton
# 22530                100 Deforest Rd, Montauk, NY, 11954             Montauk
# 60553  100 Overlook Ter Apt 312, New York City, NY, 1...       New York City
# 79185  100 S Washington Avenue, Dunellen Borough, NJ,...    Dunellen Borough
# 60549                  100 W 12th St, Bayonne, NJ, 07002             Bayonne
# 71006         100 W 93rd St Apt 14B, New York, NY, 10025            New York
#
#                state  house_size  sold_date
# 23388   Rhode Island      1250.0        NaN
# 23251   Rhode Island      3108.0        NaN
# 23224   Rhode Island         NaN        NaN
# 22019   Rhode Island         NaN        NaN
# 23257   Rhode Island      3000.0        NaN
# 39572    Connecticut      2500.0        NaN
# 39571    Connecticut      2721.0        NaN
# 39568    Connecticut      1953.0        NaN
# 69279     New Jersey      3060.0        NaN
# 69280     New Jersey      3020.0        NaN
# 162      Puerto Rico         NaN        NaN
# 28453          Maine         NaN        NaN
# 17472  Massachusetts      4172.0        NaN
# 17473  Massachusetts      3605.0        NaN
# 17471  Massachusetts      4053.0        NaN
# 22530       New York       590.0        NaN
# 60553       New York         NaN        NaN
# 79185     New Jersey      1629.0        NaN
# 60549     New Jersey         NaN   4/5/2003
# 71006       New York       739.0  11/2/2017

# %% [markdown]
# This step may be an over-stretch for others. But I am trying to prune the dataset to the best rationale state possible.
#
# By default, duplicated uses Keep=First which keeps first occurrence and shows the rest as duplicate. But by doing the above, it is seen that price, bed, bath, acre_lot, and house_size of the same full_address may differ.
#
# Assumptions are that, just as there were over 87% of the dataset were duplicates, the real estate dataset was gathered from different agencies and  sources which led to duplicates of properties. Also, data about the same property were gathered at differet states hence difference in beds, baths, house size designed and allotted for them.
#
# Other observation is, the duplicate with the highest prices has higher number of bed, bath, and/or house_size.
#
# On this basis, I would assume that the duplicate with the highest price and house_size represents the final state of the duplicate to be sold and therefore, their entry with the highest prices should be kept and others dropped.

# %%
# df2[df2.full_address.duplicated(keep=False)].sort_values(by=['full_address', 'house_size'], ascending=True).head(20)

# %%
# df2[df2.full_address.duplicated(keep=False)].sort_values(by=['full_address', 'price', 'house_size', 'sold_date'], ascending=True).reset_index(drop=True).head(20)

# %%
# df2[df2.full_address.duplicated(keep=False)].sort_values(by=['full_address', 'price', 'house_size', 'sold_date'], ascending=False).reset_index(drop=True).tail(20)

# %% [markdown]
# The above 3 cells which have been commented out were done to check different sorting effects to decide how to sort the list

# %%
# creating a sorter to make the code look simple and meaningful when applied.

column_sorter = ["full_address", "price", "house_size", "sold_date"]
column_sorter
# Out:
# ['full_address', 'price', 'house_size', 'sold_date']

# %%
df3 = df2.sort_values(by=column_sorter).reset_index(drop=True)
df3
# Out:
#          status    price  bed  bath  acre_lot  \
# 0      for_sale  1250000  NaN   NaN     32.30
# 1      for_sale   130000  NaN   NaN      1.48
# 2      for_sale   120000  NaN   NaN      2.61
# 3      for_sale   950000  4.0   3.0      0.47
# 4      for_sale  1150000  4.0   3.0      0.47
# ...         ...      ...  ...   ...       ...
# 81366  for_sale  1850000  5.0   4.0      1.59
# 81367  for_sale  2150000  2.0   3.0       NaN
# 81368  for_sale    95000  3.0   3.0      0.06
# 81369  for_sale   150000  NaN   NaN     50.00
# 81370  for_sale   135000  5.0   2.0      0.09
#
#                                             full_address                city  \
# 0      0 0 Bay St /Judson St /Church St, Tiverton, RI...            Tiverton
# 1                     0 52 Range Ave, Taunton, MA, 02780             Taunton
# 2                     0 53 Range Ave, Taunton, MA, 02780             Taunton
# 3               0 A1 Morrison Ave, Middletown, RI, 02842          Middletown
# 4               0 A3 Morrison Ave, Middletown, RI, 02842          Middletown
# ...                                                  ...                 ...
# 81366      Zero Bridge St Lot Eight, Hamilton, MA, 01982            Hamilton
# 81367      Zero Worcester Sq Unit TH1, Boston, MA, 02118              Boston
# 81368  Zh-11 Calle 31 Urb Riverview # 501-826608, Bay...             Bayamon
# 81369             Zorn Dr, Middletown Springs, VT, 05757  Middletown Springs
# 81370         Zorzal 84 Bo Cuchillas, Morovis, PR, 00687             Morovis
#
#                state  house_size sold_date
# 0       Rhode Island         NaN       NaN
# 1      Massachusetts         NaN       NaN
# 2      Massachusetts         NaN       NaN
# 3       Rhode Island      2500.0       NaN
# 4       Rhode Island      3120.0       NaN
# ...              ...         ...       ...
# 81366  Massachusetts      4800.0       NaN
# 81367  Massachusetts      1514.0       NaN
# 81368    Puerto Rico       752.0       NaN
# 81369        Vermont         NaN       NaN
# 81370    Puerto Rico      1414.0       NaN
#
# [81371 rows x 10 columns]

# %%
# showing ALL duplicates to confirm if the highest price and other values are the last of the duplicates.

df3[df3.full_address.duplicated(keep=False)].head(20)
# Out:
#               status    price  bed  bath  acre_lot  \
# 46          for_sale    49000  NaN   NaN      0.12
# 47          for_sale   399999  3.0   2.0      0.12
# 106         for_sale  1200000  NaN   NaN      0.25
# 107         for_sale  1250000  4.0   4.0      0.17
# 108         for_sale  3495000  5.0   7.0      0.31
# 143         for_sale   799000  NaN   NaN      1.07
# 144         for_sale  2495000  4.0   4.0      0.92
# 195         for_sale   779500  4.0   3.0      0.69
# 196         for_sale   859500  4.0   3.0      0.54
# 703   ready_to_build   796995  2.0   NaN       NaN
# 704   ready_to_build   816995  2.0   NaN       NaN
# 705   ready_to_build   831995  3.0   NaN       NaN
# 706   ready_to_build   842995  3.0   NaN       NaN
# 886   ready_to_build   970995  3.0   NaN       NaN
# 887   ready_to_build   970995  3.0   NaN       NaN
# 888   ready_to_build  1038995  3.0   NaN       NaN
# 1047        for_sale   160000  NaN   NaN     14.34
# 1048        for_sale   290000  NaN   NaN     16.22
# 1708        for_sale  1200000  3.0   2.0    165.00
# 1709        for_sale  1200000  NaN   NaN    165.00
#
#                                    full_address                city  \
# 46             0 Erie St, Woonsocket, RI, 02895          Woonsocket
# 47             0 Erie St, Woonsocket, RI, 02895          Woonsocket
# 106   0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 107   0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 108   0 Newport Beach Dr, Portsmouth, RI, 02871          Portsmouth
# 143        0 Rumstick Rd, Barrington, RI, 02806          Barrington
# 144        0 Rumstick Rd, Barrington, RI, 02806          Barrington
# 195           0 Whitman Way, Lincoln, RI, 02865             Lincoln
# 196           0 Whitman Way, Lincoln, RI, 02865             Lincoln
# 703           1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 704           1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 705           1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 706           1 Enclave Dr, Trumbull, CT, 06611            Trumbull
# 886    1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 887    1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 888    1 Lake St, Upper Saddle River, NJ, 07458  Upper Saddle River
# 1047                 1 Pr, Cabo Rojo, PR, 00623           Cabo Rojo
# 1048                 1 Pr, Cabo Rojo, PR, 00623           Cabo Rojo
# 1708         10 Gables End, Belgrade, ME, 04917            Belgrade
# 1709         10 Gables End, Belgrade, ME, 04917            Belgrade
#
#              state  house_size sold_date
# 46    Rhode Island         NaN       NaN
# 47    Rhode Island      1250.0       NaN
# 106   Rhode Island         NaN       NaN
# 107   Rhode Island      3108.0       NaN
# 108   Rhode Island      5056.0       NaN
# 143   Rhode Island         NaN       NaN
# 144   Rhode Island      4250.0       NaN
# 195   Rhode Island      3000.0       NaN
# 196   Rhode Island      3600.0       NaN
# 703    Connecticut      1953.0       NaN
# 704    Connecticut      1880.0       NaN
# 705    Connecticut      2500.0       NaN
# 706    Connecticut      2721.0       NaN
# 886     New Jersey      3055.0       NaN
# 887     New Jersey      3060.0       NaN
# 888     New Jersey      3020.0       NaN
# 1047   Puerto Rico         NaN       NaN
# 1048   Puerto Rico         NaN       NaN
# 1708         Maine      2600.0       NaN
# 1709         Maine         NaN       NaN

# %% [markdown]
# It can be seen that the highest are indeed the last. so we can use keep='last' to isolate them and we can then drop the rest making sure we are only keeping the duplicates with the highest values on the assumption that they represent the latest information fo the duplicates in terms of their number of beds, bath, house_size which all influence the price

# %%
# isolating the last "updated" values leaving those to be dropped

df3[df3.full_address.duplicated(keep='last')]
# Out:
#          status    price  bed  bath  acre_lot  \
# 46     for_sale    49000  NaN   NaN      0.12
# 106    for_sale  1200000  NaN   NaN      0.25
# 107    for_sale  1250000  4.0   4.0      0.17
# 143    for_sale   799000  NaN   NaN      1.07
# 195    for_sale   779500  4.0   3.0      0.69
# ...         ...      ...  ...   ...       ...
# 81145  for_sale  1029500  3.0   4.0      0.01
# 81180  for_sale    38500  NaN   NaN      1.20
# 81211  for_sale    23000  NaN   NaN      1.13
# 81310  for_sale    79000  NaN   NaN      0.70
# 81331  for_sale   225000  NaN   NaN      5.02
#
#                                     full_address         city          state  \
# 46              0 Erie St, Woonsocket, RI, 02895   Woonsocket   Rhode Island
# 106    0 Newport Beach Dr, Portsmouth, RI, 02871   Portsmouth   Rhode Island
# 107    0 Newport Beach Dr, Portsmouth, RI, 02871   Portsmouth   Rhode Island
# 143         0 Rumstick Rd, Barrington, RI, 02806   Barrington   Rhode Island
# 195            0 Whitman Way, Lincoln, RI, 02865      Lincoln   Rhode Island
# ...                                          ...          ...            ...
# 81145                        Watchung, NJ, 07069     Watchung     New Jersey
# 81180            West St, Sandisfield, MA, 01255  Sandisfield  Massachusetts
# 81211            Whipple Way, Milford, PA, 18337      Milford   Pennsylvania
# 81310          Wiscasset Rd, Boothbay, ME, 04537     Boothbay          Maine
# 81331          Woodville Rd, Falmouth, ME, 04105     Falmouth          Maine
#
#        house_size sold_date
# 46            NaN       NaN
# 106           NaN       NaN
# 107        3108.0       NaN
# 143           NaN       NaN
# 195        3000.0       NaN
# ...           ...       ...
# 81145      3032.0       NaN
# 81180         NaN       NaN
# 81211         NaN       NaN
# 81310         NaN       NaN
# 81331         NaN       NaN
#
# [772 rows x 10 columns]

# %%
# dropping duplicates in full address keeping the last ones and resetting the index 

df4 = df3.drop_duplicates(subset='full_address', keep='last').reset_index(drop=True)
df4
# Out:
#          status    price  bed  bath  acre_lot  \
# 0      for_sale  1250000  NaN   NaN     32.30
# 1      for_sale   130000  NaN   NaN      1.48
# 2      for_sale   120000  NaN   NaN      2.61
# 3      for_sale   950000  4.0   3.0      0.47
# 4      for_sale  1150000  4.0   3.0      0.47
# ...         ...      ...  ...   ...       ...
# 80594  for_sale  1850000  5.0   4.0      1.59
# 80595  for_sale  2150000  2.0   3.0       NaN
# 80596  for_sale    95000  3.0   3.0      0.06
# 80597  for_sale   150000  NaN   NaN     50.00
# 80598  for_sale   135000  5.0   2.0      0.09
#
#                                             full_address                city  \
# 0      0 0 Bay St /Judson St /Church St, Tiverton, RI...            Tiverton
# 1                     0 52 Range Ave, Taunton, MA, 02780             Taunton
# 2                     0 53 Range Ave, Taunton, MA, 02780             Taunton
# 3               0 A1 Morrison Ave, Middletown, RI, 02842          Middletown
# 4               0 A3 Morrison Ave, Middletown, RI, 02842          Middletown
# ...                                                  ...                 ...
# 80594      Zero Bridge St Lot Eight, Hamilton, MA, 01982            Hamilton
# 80595      Zero Worcester Sq Unit TH1, Boston, MA, 02118              Boston
# 80596  Zh-11 Calle 31 Urb Riverview # 501-826608, Bay...             Bayamon
# 80597             Zorn Dr, Middletown Springs, VT, 05757  Middletown Springs
# 80598         Zorzal 84 Bo Cuchillas, Morovis, PR, 00687             Morovis
#
#                state  house_size sold_date
# 0       Rhode Island         NaN       NaN
# 1      Massachusetts         NaN       NaN
# 2      Massachusetts         NaN       NaN
# 3       Rhode Island      2500.0       NaN
# 4       Rhode Island      3120.0       NaN
# ...              ...         ...       ...
# 80594  Massachusetts      4800.0       NaN
# 80595  Massachusetts      1514.0       NaN
# 80596    Puerto Rico       752.0       NaN
# 80597        Vermont         NaN       NaN
# 80598    Puerto Rico      1414.0       NaN
#
# [80599 rows x 10 columns]

# %%
# confirming all duplicates in full_address column are gone

df4.full_address.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# the result False shows there are no duplicates. At this point, there is confidence the dataset has unique properties listed with no perfect duplicates and only updated property listings are kept. This allows to confidently trust that any analysis performed are true to the outlook of the market.

# %%
# finding columns with missing values again.

df4.isnull().sum()
# Out:
# status              0
# price               0
# bed             13737
# bath            12368
# acre_lot        21473
# full_address        0
# city               21
# state               0
# house_size      27260
# sold_date       41880
# dtype: int64

# %% [markdown]
# While those are missing value counts, I am okay with keeping those data instances per the analysis. At least for now.

# %%
df4.describe().round(1)
# Out:
#              price      bed     bath  acre_lot  house_size
# count      80599.0  66862.0  68231.0   59126.0     53339.0
# mean      910435.5      3.4      2.6      21.6      2234.8
# std      3691066.1      2.0      1.8    1084.2      6888.8
# min            0.0      1.0      1.0       0.0       100.0
# 25%       259900.0      2.0      2.0       0.1      1154.0
# 50%       469000.0      3.0      2.0       0.4      1700.0
# 75%       830000.0      4.0      3.0       1.4      2570.0
# max    875000000.0    123.0    198.0  100000.0   1450112.0

# %% [markdown]
# The descriptive stats shows huge standard deviation with max value exceeding 75% of the data astronomically. The mean is also greater than 75% of the data which means the upper 25% must be huge price points to drive the mean that high above 75% of the data.

# %%
# plotting the price on box plot to see the outlier distribution

plt.figure(figsize=(10, 1))
sns.boxplot(data=df4, x='price')
plt.title('Price Boxplot')
plt.xlabel('Price')
plt.ylabel('')

plt.show()

# %%
# finding the property costing over 8*1e8 = $800,000,000

most_expensive = df4[df4.price > 8*1e8]
most_expensive
# Out:
#          status      price  bed  bath  acre_lot  \
# 72833  for_sale  875000000  9.0   2.0       NaN
#
#                                          full_address   city     state  \
# 72833  952 E 223 St Units 4858 & 66, Bronx, NY, 10458  Bronx  New York
#
#        house_size   sold_date
# 72833      2440.0  12/30/2002

# %%
# removing the most expensive property

df5 = df4.drop(most_expensive.index)

# %%
# plotting the new dataframe to see the new distribution

plt.figure(figsize=(10,1))
sns.boxplot(x='price', data=df5)
plt.title('Price Boxplot')
plt.xlabel('Price')

plt.show()

# %%
# looking at the location of properties selling above  $0.4e8

df5[df5.price > 0.4e8]
# Out:
#          status      price    bed   bath  acre_lot  \
# 6254   for_sale   66000000    4.0    6.0       NaN
# 14572  for_sale   45000000    4.0    4.0       NaN
# 17893  for_sale   53000000    6.0    9.0       NaN
# 21704  for_sale  100000000   10.0   10.0     60.92
# 23106  for_sale   55000000    6.0    8.0       NaN
# 23416  for_sale   79000000    1.0    1.0       NaN
# 27102  for_sale   45000000   16.0   21.0       NaN
# 27103  for_sale   45000000   16.0   21.0      0.10
# 28735  for_sale   62000000    5.0    6.0       NaN
# 28736  for_sale   62000000    5.0    6.0       NaN
# 31224  for_sale   49900000    5.0    7.0      3.43
# 35943  for_sale   42500000    5.0    8.0      0.54
# 37389  for_sale   45000000    4.0    5.0       NaN
# 48656  for_sale  120000000  123.0  123.0       NaN
# 49348  for_sale   68000000    6.0    9.0       NaN
# 50490  for_sale   60000000    9.0   10.0    400.00
# 55410  for_sale   63815000    4.0    4.0       NaN
# 59780  for_sale   46880000    NaN    NaN      0.37
# 66898  for_sale   45000000    6.0    9.0       NaN
# 73672  for_sale   44000000    NaN    NaN       NaN
# 76044  for_sale  100000000   10.0   10.0     60.92
#
#                                             full_address           city  \
# 6254            111 W 57th St Ph 72, New York, NY, 10019       New York
# 14572  15 Central Park W Ph 41, New York City, NY, 10023  New York City
# 17893  165 Charles St Unit Triplex, New York City, NY...  New York City
# 21704                     19 Great Is, Darien, CT, 06820         Darien
# 23106   2 E 67th St Unit 5FULLFLOOR, New York, NY, 10065       New York
# 23416       2 Park Pl Unit Pinnacle, New York, NY, 10007       New York
# 27102           217-219 W Broadway, Manhattan, NY, 10013      Manhattan
# 27103       217-219 W Broadway, New York City, NY, 10013  New York City
# 28735     23 E 22nd St Unit Ph, New York City, NY, 10010  New York City
# 28736          23 E 22nd St Unit Ph, New York, NY, 10010       New York
# 31224    25 Columbus Cir Ph 80, New York City, NY, 10019  New York City
# 35943    293 Lafayette St Ph 1, New York City, NY, 10012  New York City
# 37389             30 Park Pl Ph 81, Manhattan, NY, 10007      Manhattan
# 48656           421 W 250th St, New York City, NY, 10471  New York City
# 49348          432 Park Ave Unit 71, New York, NY, 10022       New York
# 50490             450 Brickyard Rd, Woodstock, CT, 06281      Woodstock
# 55410            53 53rd St W Ph 76, New York, NY, 10019       New York
# 59780                  6020 3rd Ave, Brooklyn, NY, 11220       Brooklyn
# 66898       781 Fifth Ave Unit 18FL, New York, NY, 10022       New York
# 73672              991 5th Ave, New York City, NY, 10028  New York City
# 76044                        Great Is, Darien, CT, 06820         Darien
#
#              state  house_size  sold_date
# 6254      New York      7130.0        NaN
# 14572     New York      4024.0        NaN
# 17893     New York      9607.0        NaN
# 21704  Connecticut     13107.0        NaN
# 23106     New York         NaN        NaN
# 23416     New York      9680.0        NaN
# 27102     New York     29363.0        NaN
# 27103     New York     29363.0        NaN
# 28735     New York      6850.0        NaN
# 28736     New York      6850.0        NaN
# 31224     New York      8274.0        NaN
# 35943     New York      7241.0        NaN
# 37389     New York      5443.0   2/1/2017
# 48656     New York         NaN  6/29/2012
# 49348     New York      8108.0        NaN
# 50490  Connecticut     18777.0  8/28/2003
# 55410     New York      7973.0        NaN
# 59780     New York         NaN        NaN
# 66898     New York         NaN        NaN
# 73672     New York     14000.0        NaN
# 76044  Connecticut     13107.0        NaN

# %% [markdown]
# These are prices of properties which truly can have high disparities in prices. The most expensive was too high off so removing it was okay. While the prices > 0.8e8 may be perceived as outliers, I will make the decision to keep them as they are realistic. Most are in New York

# %%
# finding the relationship between prices and no. of bathrooms

plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='bath', data=df5)
plt.title('Scatter Plot')
plt.xlabel('Price')
plt.ylabel('Number of Bathrooms')
plt.show()

# %%
# finding the relationship between prices and no. of bathrooms

plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='bed', data=df5)
plt.title('Scatter Plot')
plt.xlabel('Price')
plt.ylabel('Number of Bedrooms')
plt.show()

# %% [markdown]
# The higher the number of bathrooms does not directly lead to increase in prices across. Also properties with baths over 50 still have lower prices. Wonder what state have these huge properties but with comparatively lower prices.

# %%
# finding the location of properries 

df5[df5.bath > 50]
# Out:
#          status      price    bed   bath  acre_lot  \
# 48656  for_sale  120000000  123.0  123.0       NaN
# 58867  for_sale    5300000   99.0  198.0      0.29
# 66609  for_sale   15150000   86.0   56.0      1.32
# 67270  for_sale   14950000   60.0   51.0      1.01
#
#                                            full_address           city  \
# 48656          421 W 250th St, New York City, NY, 10471  New York City
# 58867        6 Jefferson St Apt 12, Winthrop, MA, 02152       Winthrop
# 66609  77-79 and 93 Arlington St, Framingham, MA, 01702     Framingham
# 67270                    8 Banton St, Boston, MA, 02124         Boston
#
#                state  house_size  sold_date
# 48656       New York         NaN  6/29/2012
# 58867  Massachusetts     14462.0        NaN
# 66609  Massachusetts     35666.0        NaN
# 67270  Massachusetts     38442.0        NaN

# %% [markdown]
# Looks like Massachusetts is the state with properties having decent prices comparable to house size and higher no. of beds and bathrooms.

# %%
# finding missing values

df5.isnull().sum()
# Out:
# status              0
# price               0
# bed             13737
# bath            12368
# acre_lot        21472
# full_address        0
# city               21
# state               0
# house_size      27260
# sold_date       41880
# dtype: int64

# %% [markdown]
# Empty values may affect various analysis that could be done. Price is okay. Sold date having almost half the total number missing is fine since we earlier assumed those houses have not yet been sold.
#
# Let's start with City since it has the least missing values.

# %%
# finding missing cities

missing_cities = df5[df5.city.isnull()]
missing_cities
# Out:
#          status    price  bed  bath  acre_lot  \
# 9206   for_sale    79000  NaN   NaN      0.50
# 12605  for_sale   935000  NaN   NaN      3.91
# 16106  for_sale   199000  NaN   NaN      1.14
# 17731  for_sale   165000  NaN   NaN      0.44
# 18870  for_sale   125000  NaN   NaN      0.94
# 22272  for_sale    55000  NaN   NaN      0.39
# 24194  for_sale    45000  NaN   NaN      0.91
# 26062  for_sale    90000  NaN   NaN      1.19
# 29173  for_sale   750000  NaN   NaN      0.44
# 30413  for_sale   197500  1.0   1.0       NaN
# 30578  for_sale    72000  NaN   NaN      0.84
# 39605  for_sale   569000  3.0   3.0      0.13
# 46342  for_sale    64000  NaN   NaN      0.60
# 48242  for_sale   649000  NaN   NaN      1.83
# 61423  for_sale   495000  2.0   1.0    110.00
# 62864  for_sale   598000  2.0   1.0       NaN
# 67950  for_sale   120000  NaN   NaN      0.50
# 68857  for_sale   449000  5.0   2.0      0.14
# 71383  for_sale  2700000  5.0   7.0     13.34
# 72646  for_sale    25000  NaN   NaN      0.25
# 72933  for_sale    59000  NaN   NaN      0.49
#
#                                      full_address city           state  \
# 9206                   123 Catherines Hope Eb, VI  NaN  Virgin Islands
# 12605                           14 Diamond Pr, VI  NaN  Virgin Islands
# 16106                      155-A La Vallee Nb, VI  NaN  Virgin Islands
# 17731                163 Union and Mt Wash Ea, VI  NaN  Virgin Islands
# 18870                        17 Prosperity Nb, VI  NaN  Virgin Islands
# 22272                        192 La Vallee Nb, VI  NaN  Virgin Islands
# 24194                             20 River Pr, VI  NaN  Virgin Islands
# 26062                       21 N Grapetree Eb, VI  NaN  Virgin Islands
# 29173                230 S Stevens Ave, NJ, 07008  NaN      New Jersey
# 30413                          240 St John Qu, VI  NaN  Virgin Islands
# 30578                242 Union and Mt Wash Ea, VI  NaN  Virgin Islands
# 39605                   32 Devereux Dr, NJ, 08001  NaN      New Jersey
# 46342                         4 Prosperity Nb, VI  NaN  Virgin Islands
# 48242                          42 43 Shoys Ea, VI  NaN  Virgin Islands
# 61423               641 State Route 82, NY, 12523  NaN        New York
# 62864  689 Luis M Marin Blvd Unit 1009, NJ, 07010  NaN      New Jersey
# 67950                      8-B Teagues Bay Eb, VI  NaN  Virgin Islands
# 68857               824-26 Berckman St, NJ, 07062  NaN      New Jersey
# 71383              9-11 Putnam Park Rd, CT, 06896  NaN     Connecticut
# 72646                     94V I Corp Lands Pr, VI  NaN  Virgin Islands
# 72933                        96 Hard Labor Pr, VI  NaN  Virgin Islands
#
#        house_size sold_date
# 9206          NaN       NaN
# 12605         NaN       NaN
# 16106         NaN       NaN
# 17731         NaN       NaN
# 18870         NaN       NaN
# 22272         NaN       NaN
# 24194         NaN       NaN
# 26062         NaN       NaN
# 29173         NaN       NaN
# 30413      1100.0       NaN
# 30578         NaN       NaN
# 39605      2434.0       NaN
# 46342         NaN       NaN
# 48242         NaN       NaN
# 61423      1177.0       NaN
# 62864       992.0       NaN
# 67950         NaN       NaN
# 68857      1620.0       NaN
# 71383      6343.0       NaN
# 72646         NaN       NaN
# 72933         NaN       NaN

# %% [markdown]
# Inspecting if their full addresses could reveal their cities doesn't work. Some libraries like usaddress or APIs like Google Geocoding API or Nominatim (OpenStreetMap) could be tried to identify the cties but it is not worth it for this dataset as there are only 21 of them. I have made the decision to drop them fromt he dataset.

# %%
# removing rows with empty cities

df5.dropna(subset='city', inplace=True)

# %%
# confirming the emty cities are removed

df5.isnull().sum()
# Out:
# status              0
# price               0
# bed             13722
# bath            12353
# acre_lot        21470
# full_address        0
# city                0
# state               0
# house_size      27245
# sold_date       41859
# dtype: int64

# %% [markdown]
# Filling the missing bed and bath with their mean or median would not be good as housing prices have irregular correlation with no. of beds and baths as we found in the scatter plots. The location determines the prices therefore it would make more sense to fill the empty values with mean/median values from their respective states or cities. Using the cities would reduce margin of error compared to state and compared to the whole dataset.

# %%
# calculating the medians of each city

city_medians = df5.groupby('city')[['bed', 'bath', 'acre_lot', 'house_size']].transform('median')
city_medians
# Out:
#        bed  bath  acre_lot  house_size
# 0      3.0   2.0     0.410      1450.5
# 1      3.0   2.0     0.340      1859.0
# 2      3.0   2.0     0.340      1859.0
# 3      3.0   2.0     0.425      1579.0
# 4      3.0   2.0     0.425      1579.0
# ...    ...   ...       ...         ...
# 80594  4.0   3.0     0.460      2247.0
# 80595  2.0   2.0     0.040      1270.0
# 80596  3.0   2.0     0.090      1214.0
# 80597  3.0   2.0    18.050      1716.0
# 80598  5.0   2.0     0.860      1620.0
#
# [80577 rows x 4 columns]

# %%
# filling the missing bed, bath, acre_lot and house_size values in each city with it's median

df5['bed'] = df5['bed'].fillna(city_medians['bed'])
df5['bath'] = df5['bath'].fillna(city_medians['bath'])
df5['acre_lot'] = df5['acre_lot'].fillna(city_medians['acre_lot'])
df5['house_size'] = df5['house_size'].fillna(city_medians['house_size'])

# %%
# confirming that the missing values are filled

df5.isnull().sum()
# Out:
# status              0
# price               0
# bed               177
# bath              211
# acre_lot          108
# full_address        0
# city                0
# state               0
# house_size        551
# sold_date       41859
# dtype: int64

# %% [markdown]
# After filling the missing values, there are few rows with Nan in them. they are going to be dropped.

# %%
# Dropping Remaining empty cells

df5.dropna(subset=['bed', 'bath', 'acre_lot', 'house_size'], inplace=True)

# %%
# confirming they're removed

df5.isnull().sum()
# Out:
# status              0
# price               0
# bed                 0
# bath                0
# acre_lot            0
# full_address        0
# city                0
# state               0
# house_size          0
# sold_date       41454
# dtype: int64

# %% [markdown]
# As stated earlier, the missing dates are left intentionally as they may signify properties that are not yet sold.

# %%
# checking info about the dataset like data types

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79881 entries, 0 to 80598
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        79881 non-null  object
#  1   price         79881 non-null  int64
#  2   bed           79881 non-null  float64
#  3   bath          79881 non-null  float64
#  4   acre_lot      79881 non-null  float64
#  5   full_address  79881 non-null  object
#  6   city          79881 non-null  object
#  7   state         79881 non-null  object
#  8   house_size    79881 non-null  float64
#  9   sold_date     38427 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 6.7+ MB

# %%
# Check the columns to determine the right file types to assign and any changes necessary

df5.head(60)
# Out:
#       status    price  bed  bath  acre_lot  \
# 0   for_sale  1250000  3.0   2.0     32.30
# 1   for_sale   130000  3.0   2.0      1.48
# 2   for_sale   120000  3.0   2.0      2.61
# 3   for_sale   950000  4.0   3.0      0.47
# 4   for_sale  1150000  4.0   3.0      0.47
# 5   for_sale   769900  4.0   3.0      0.69
# 6   for_sale  1500000  3.0   2.0    136.00
# 7   for_sale   300000  3.0   3.0      0.40
# 8   for_sale   350000  3.0   2.0     58.00
# 9   for_sale    50000  3.0   3.0      0.20
# 10  for_sale    75000  4.0   2.0      0.29
# 11  for_sale    99900  3.0   2.0      0.23
# 12  for_sale    59000  3.0   3.0      1.70
# 13  for_sale  1200000  4.0   3.0      3.54
# 14  for_sale   449900  3.0   3.0      0.11
# 15  for_sale    20000  3.0   2.5      2.33
# 16  for_sale   595000  3.0   2.0      1.43
# 17  for_sale   145000  3.0   2.0      0.16
# 18  for_sale   500000  3.0   3.0      5.47
# 19  for_sale    32500  3.0   2.0      1.05
# 20  for_sale   469200  3.0   2.0     26.64
# 21  for_sale    50000  3.0   2.0      2.00
# 22  for_sale    15000  3.0   2.0      0.25
# 23  for_sale    99000  3.0   2.0      0.93
# 24  for_sale  2000000  3.0   3.0      2.03
# 25  for_sale  2900000  4.0   5.0      0.69
# 26  for_sale  1500000  3.0   3.0      0.68
# 27  for_sale    55000  3.0   2.0      1.59
# 28  for_sale    25000  3.0   1.0      0.50
# 29  for_sale    30000  3.0   1.0      0.50
# 30  for_sale    50000  3.0   2.0      0.28
# 31  for_sale    75000  3.0   2.0      0.11
# 32  for_sale   350000  3.0   2.0      0.94
# 33  for_sale   849900  3.0   3.0      0.46
# 34  for_sale   849900  3.0   3.0      0.46
# 35  for_sale   300000  3.0   3.0      0.14
# 36  for_sale   599900  3.0   2.0      0.21
# 37  for_sale   100000  3.0   2.0     27.50
# 38  for_sale    99000  3.0   2.0      0.11
# 39  for_sale    49000  3.0   3.0      3.31
# 40  for_sale    49000  3.0   3.0      3.47
# 41  for_sale    65000  3.0   2.0      0.20
# 42  for_sale    59900  3.0   2.0      0.09
# 43  for_sale    99900  3.0   2.0      0.20
# 44  for_sale    39900  3.0   2.0      0.30
# 45  for_sale    75000  3.0   2.0      0.26
# 46  for_sale   399999  3.0   2.0      0.12
# 47  for_sale   379000  3.0   2.0     42.25
# 48  for_sale   225000  3.0   2.0      4.57
# 49  for_sale   450000  3.0   3.0      1.96
# 50  for_sale   199900  3.0   2.0      6.63
# 51  for_sale    75000  3.0   2.0      0.09
# 52  for_sale    75000  3.0   2.0      0.23
# 53  for_sale    50000  3.0   2.0      0.09
# 54  for_sale   279900  3.0   3.0      3.00
# 55  for_sale    99900  3.0   2.0      2.99
# 56  for_sale   649900  3.0   2.0     24.42
# 57  for_sale   349000  3.0   2.0      1.15
# 58  for_sale   899000  3.0   2.0      1.88
# 59  for_sale   375000  3.0   2.0     16.31
#
#                                          full_address              city  \
# 0   0 0 Bay St /Judson St /Church St, Tiverton, RI...          Tiverton
# 1                  0 52 Range Ave, Taunton, MA, 02780           Taunton
# 2                  0 53 Range Ave, Taunton, MA, 02780           Taunton
# 3            0 A1 Morrison Ave, Middletown, RI, 02842        Middletown
# 4            0 A3 Morrison Ave, Middletown, RI, 02842        Middletown
# 5       0 Abbott Run Valley Rd, Cumberland, RI, 02864        Cumberland
# 6                 0 Adelaide Rd, Glocester, RI, 02859         Glocester
# 7           0 Alton Bradford Rd, Hopkinton, RI, 02894         Hopkinton
# 8            0 Alton Bradford Rd, Richmond, RI, 02833          Richmond
# 9        0 Arrow Head Trl, South Kingstown, RI, 02879   South Kingstown
# 10                   0 Ashmun, Springfield, MA, 01101       Springfield
# 11                 0 Atwells Ave, Johnston, RI, 02919          Johnston
# 12                0 Bayberry Dr, Hopkinton, RI, 02804         Hopkinton
# 13          0 Beacon Hill Rd, Block Island, RI, 02807      Block Island
# 14                0 Benjamin St, Pawtucket, RI, 02861         Pawtucket
# 15  0 Block 3101 Landis Ave Lot 31, Pittsgrove, NJ...        Pittsgrove
# 16             0 Blossom Way, Narragansett, RI, 02882      Narragansett
# 17          0 Boston Neck Rd, Narragansett, RI, 02882      Narragansett
# 18        0 Bridgetown Rd, South Kingstown, RI, 02874   South Kingstown
# 19         0 Broadcove W Lot 52, Waldoboro, ME, 04572         Waldoboro
# 20               0 Broadway St, Woonsocket, RI, 02895        Woonsocket
# 21              0 Bronco Hwy, Burrillville, RI, 02830      Burrillville
# 22            0 Brookside Rd, Narragansett, RI, 02882      Narragansett
# 23         0 Buckeye Brook Rd, Charlestown, RI, 02813       Charlestown
# 24  0 Carnegie Harbor Dr Lot 1, Portsmouth, RI, 02871        Portsmouth
# 25  0 Carnegie Harbor Dr Lot 20, Portsmouth, RI, 0...        Portsmouth
# 26        0 Carnegie Harbor Dr, Portsmouth, RI, 02871        Portsmouth
# 27           0 Centennial St, Burrillville, RI, 02830      Burrillville
# 28              0 Center St Lot 3, Morrill, ME, 04952           Morrill
# 29              0 Center St Lot 4, Morrill, ME, 04952           Morrill
# 30             0 Channing Rd, Narragansett, RI, 02882      Narragansett
# 31                 0 Charlotte Dr, Warwick, RI, 02818           Warwick
# 32               0 Chase Ln Lot 2, Lincoln, RI, 02865           Lincoln
# 33            0 Coletta Ct Lot 1, Cranston, RI, 02921          Cranston
# 34            0 Coletta Ct Lot 2, Cranston, RI, 02921          Cranston
# 35         0 Common Fence Blvd, Portsmouth, RI, 02871        Portsmouth
# 36  0 Curtis Corner Rd Lot 24, South Kingstown, RI...   South Kingstown
# 37                0 Danielson Pike, Foster, RI, 02825            Foster
# 38                  0 Davidson Rd, Warwick, RI, 02886           Warwick
# 39            0 Davis Lot 2, New Braintree, MA, 01531     New Braintree
# 40         0 Davis Rd Lot 3, New Braintree, MA, 01531     New Braintree
# 41                0 Doe Xing, Burrillville, RI, 02859      Burrillville
# 42                   0 Dundas Ave, Warwick, RI, 02889           Warwick
# 43                    0 Eagle St, Johnston, RI, 02919          Johnston
# 44                    0 Echo Rd, Glocester, RI, 02859         Glocester
# 45                    0 Elm St, Woonsocket, RI, 02895        Woonsocket
# 46                   0 Erie St, Woonsocket, RI, 02895        Woonsocket
# 47                   0 Evans Rd, Glocester, RI, 02814         Glocester
# 48           0 Fairfield St Lot A, Oakland, ME, 04963           Oakland
# 49  0 Fairview Ln and Bayside Ave Ln, Portsmouth, ...        Portsmouth
# 50               0 Farnum Pike, Smithfield, RI, 02917        Smithfield
# 51                  0 Foch Ave, Woonsocket, RI, 02895        Woonsocket
# 52            0 Forbes St, East Providence, RI, 02915   East Providence
# 53              0 Forest Hill Dr, Johnston, RI, 02919          Johnston
# 54           0 Gardner Rd, South Kingstown, RI, 02879   South Kingstown
# 55            0 Great Rd, North Smithfield, RI, 02896  North Smithfield
# 56                0 Green Bush Rd, Warwick, RI, 02818           Warwick
# 57         0 Green Meadow Dr, Narragansett, RI, 02882      Narragansett
# 58                 0 Greene Ln, Middletown, RI, 02842        Middletown
# 59              0 Griffin St, Burrillville, RI, 02859      Burrillville
#
#             state  house_size sold_date
# 0    Rhode Island      1450.5       NaN
# 1   Massachusetts      1859.0       NaN
# 2   Massachusetts      1859.0       NaN
# 3    Rhode Island      2500.0       NaN
# 4    Rhode Island      3120.0       NaN
# 5    Rhode Island      2600.0       NaN
# 6    Rhode Island      1236.0       NaN
# 7    Rhode Island      2060.0       NaN
# 8    Rhode Island      1500.0       NaN
# 9    Rhode Island      1808.0       NaN
# 10  Massachusetts      1690.0       NaN
# 11   Rhode Island      1434.0       NaN
# 12   Rhode Island      2060.0       NaN
# 13   Rhode Island      2200.0       NaN
# 14   Rhode Island      1752.0       NaN
# 15     New Jersey      1027.0       NaN
# 16   Rhode Island      1686.5       NaN
# 17   Rhode Island      1686.5       NaN
# 18   Rhode Island      1808.0       NaN
# 19          Maine      1570.0       NaN
# 20   Rhode Island      2099.0       NaN
# 21   Rhode Island      1700.0       NaN
# 22   Rhode Island      1686.5       NaN
# 23   Rhode Island      1573.5       NaN
# 24   Rhode Island      1900.0       NaN
# 25   Rhode Island      4800.0       NaN
# 26   Rhode Island      1900.0       NaN
# 27   Rhode Island      1700.0       NaN
# 28          Maine      1390.0       NaN
# 29          Maine      1390.0       NaN
# 30   Rhode Island      1686.5       NaN
# 31   Rhode Island      1449.0       NaN
# 32   Rhode Island      1700.0       NaN
# 33   Rhode Island      2500.0       NaN
# 34   Rhode Island      3000.0       NaN
# 35   Rhode Island      1900.0       NaN
# 36   Rhode Island      1556.0       NaN
# 37   Rhode Island      1266.0       NaN
# 38   Rhode Island      1449.0       NaN
# 39  Massachusetts      2800.0       NaN
# 40  Massachusetts      2800.0       NaN
# 41   Rhode Island      1700.0       NaN
# 42   Rhode Island      1449.0       NaN
# 43   Rhode Island      1434.0       NaN
# 44   Rhode Island      1236.0       NaN
# 45   Rhode Island      2099.0       NaN
# 46   Rhode Island      1250.0       NaN
# 47   Rhode Island      1236.0       NaN
# 48          Maine      1588.0       NaN
# 49   Rhode Island      1900.0       NaN
# 50   Rhode Island      1596.5       NaN
# 51   Rhode Island      2099.0       NaN
# 52   Rhode Island      1352.0       NaN
# 53   Rhode Island      1434.0       NaN
# 54   Rhode Island      1808.0       NaN
# 55   Rhode Island      1955.0       NaN
# 56   Rhode Island      1449.0       NaN
# 57   Rhode Island      1686.5       NaN
# 58   Rhode Island      1579.0       NaN
# 59   Rhode Island      1700.0       NaN

# %%
# finding other dates in the field besides Nan

df5.sold_date.unique()
# Out:
# array([nan, '12/5/2017', '11/20/2019', ..., '6/8/1984', '2/11/1997',
#        '4/28/2022'], shape=(8854,), dtype=object)

# %% [markdown]
# Intentionally generated 60 rows of data to look at the numbers for bed, bath, acre_lot and house_size To determine what data type to reassign them if necessary.
#
# The bed and bath numbers are mostly decimal with .0 so we will change to integer. House_size may have decimal greater than zero but the figures are huge it makes the Decimal places unnecessary so that will be changed to integer.
#
# For acre_lot, a lot do you have decimals. They could be 0.21 and 0.09 So there will be left as float.

# %%
# Changing the Sold date to date time, Bed and bath to integers As well as house size.

df5['bed'] = df5.bed.astype(dtype=int)
df5['bath'] = df5.bath.astype(dtype=int)
df5['house_size'] = df5.house_size.astype(dtype=int)
df5['sold_date'] = pd.to_datetime(df5['sold_date'])
df5
# Out:
#          status    price  bed  bath  acre_lot  \
# 0      for_sale  1250000    3     2     32.30
# 1      for_sale   130000    3     2      1.48
# 2      for_sale   120000    3     2      2.61
# 3      for_sale   950000    4     3      0.47
# 4      for_sale  1150000    4     3      0.47
# ...         ...      ...  ...   ...       ...
# 80594  for_sale  1850000    5     4      1.59
# 80595  for_sale  2150000    2     3      0.04
# 80596  for_sale    95000    3     3      0.06
# 80597  for_sale   150000    3     2     50.00
# 80598  for_sale   135000    5     2      0.09
#
#                                             full_address                city  \
# 0      0 0 Bay St /Judson St /Church St, Tiverton, RI...            Tiverton
# 1                     0 52 Range Ave, Taunton, MA, 02780             Taunton
# 2                     0 53 Range Ave, Taunton, MA, 02780             Taunton
# 3               0 A1 Morrison Ave, Middletown, RI, 02842          Middletown
# 4               0 A3 Morrison Ave, Middletown, RI, 02842          Middletown
# ...                                                  ...                 ...
# 80594      Zero Bridge St Lot Eight, Hamilton, MA, 01982            Hamilton
# 80595      Zero Worcester Sq Unit TH1, Boston, MA, 02118              Boston
# 80596  Zh-11 Calle 31 Urb Riverview # 501-826608, Bay...             Bayamon
# 80597             Zorn Dr, Middletown Springs, VT, 05757  Middletown Springs
# 80598         Zorzal 84 Bo Cuchillas, Morovis, PR, 00687             Morovis
#
#                state  house_size sold_date
# 0       Rhode Island        1450       NaT
# 1      Massachusetts        1859       NaT
# 2      Massachusetts        1859       NaT
# 3       Rhode Island        2500       NaT
# 4       Rhode Island        3120       NaT
# ...              ...         ...       ...
# 80594  Massachusetts        4800       NaT
# 80595  Massachusetts        1514       NaT
# 80596    Puerto Rico         752       NaT
# 80597        Vermont        1716       NaT
# 80598    Puerto Rico        1414       NaT
#
# [79881 rows x 10 columns]

# %%
# seeing NaT in the result above, so checking if there are real dates in the sold_date column.

df5.sold_date.unique()
# Out:
# <DatetimeArray>
# [                'NaT', '2017-12-05 00:00:00', '2019-11-20 00:00:00',
#  '2017-06-20 00:00:00', '2006-08-14 00:00:00', '2007-01-09 00:00:00',
#  '2009-09-01 00:00:00', '2008-07-15 00:00:00', '2008-06-12 00:00:00',
#  '2020-11-02 00:00:00',
#  ...
#  '1979-06-05 00:00:00', '1976-10-23 00:00:00', '1977-10-31 00:00:00',
#  '1974-02-06 00:00:00', '1978-05-13 00:00:00', '1973-07-23 00:00:00',
#  '1994-12-05 00:00:00', '1984-06-08 00:00:00', '1997-02-11 00:00:00',
#  '2022-04-28 00:00:00']
# Length: 8854, dtype: datetime64[ns]

# %%
# checking if the 

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79881 entries, 0 to 80598
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        79881 non-null  object
#  1   price         79881 non-null  int64
#  2   bed           79881 non-null  int64
#  3   bath          79881 non-null  int64
#  4   acre_lot      79881 non-null  float64
#  5   full_address  79881 non-null  object
#  6   city          79881 non-null  object
#  7   state         79881 non-null  object
#  8   house_size    79881 non-null  int64
#  9   sold_date     38427 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 6.7+ MB

# %%
df5.describe().round(1)
# Out:
#              price      bed     bath  acre_lot  house_size  \
# count      79881.0  79881.0  79881.0   79881.0     79881.0
# mean      897243.2      3.3      2.5      15.8      2176.8
# min            0.0      1.0      1.0       0.0       100.0
# 25%       259900.0      2.0      2.0       0.1      1255.0
# 50%       469000.0      3.0      2.0       0.2      1736.0
# 75%       829000.0      4.0      3.0       1.0      2436.0
# max    120000000.0    123.0    198.0  100000.0   1450112.0
# std      2034599.1      1.8      1.7     932.6      5747.4
#
#                            sold_date
# count                          38427
# mean   2009-05-03 07:48:56.716371200
# min              1901-01-01 00:00:00
# 25%              2003-04-15 12:00:00
# 50%              2010-08-25 00:00:00
# 75%              2017-10-17 00:00:00
# max              2022-12-01 00:00:00
# std                              NaN

# %%
# finding correlation between the variables. to see the relationships between features of property.

df5.corr(numeric_only=True)
# Out:
#                price       bed      bath  acre_lot  house_size
# price       1.000000  0.242702  0.420156  0.002096    0.112875
# bed         0.242702  1.000000  0.710201  0.000320    0.157948
# bath        0.420156  0.710201  1.000000  0.000958    0.178114
# acre_lot    0.002096  0.000320  0.000958  1.000000    0.023031
# house_size  0.112875  0.157948  0.178114  0.023031    1.000000

# %%
# plotting the correlation on heatmap to easily identify which variable affects another

sns.heatmap(df5.corr(numeric_only=True), annot=True)

plt.show()

# %% [markdown]
# The heatmap shows strong correlation between number of bedrooms in a property to the number of baths which makes sense. As a property has more rooms and more bedrooms, it requires more bathrooms. It also shows a moderation correlation between number of baths and price. and lower correlation with price and no of bedrooms. the rest have very little correlation like house size

# %% [markdown]
# At this point, the data has been thoroughly cleaned up. With some basic insights gotten. The dataset will be exported to excel to generate visualizations to develop dashboards in PowerBi

# %%
# installing to import openpyxl which is used to save the dataframe to excel

# !pip install openpyxl

# %%
# importing openpyxl 

import openpyxl

# %%
df5.to_excel('cleaned_us_real_estate.xlsx')

# %%
pwd
# Out:
# '/Volumes/AnisX10pro/GitHub/real-estate-property-analysis-python'

# %%
# updating the new instaled package to requirement list 

# !pip freeze > requirements.txt

# %%
df5.head(60)
# Out:
#       status    price  bed  bath  acre_lot  \
# 0   for_sale  1250000    3     2     32.30
# 1   for_sale   130000    3     2      1.48
# 2   for_sale   120000    3     2      2.61
# 3   for_sale   950000    4     3      0.47
# 4   for_sale  1150000    4     3      0.47
# 5   for_sale   769900    4     3      0.69
# 6   for_sale  1500000    3     2    136.00
# 7   for_sale   300000    3     3      0.40
# 8   for_sale   350000    3     2     58.00
# 9   for_sale    50000    3     3      0.20
# 10  for_sale    75000    4     2      0.29
# 11  for_sale    99900    3     2      0.23
# 12  for_sale    59000    3     3      1.70
# 13  for_sale  1200000    4     3      3.54
# 14  for_sale   449900    3     3      0.11
# 15  for_sale    20000    3     2      2.33
# 16  for_sale   595000    3     2      1.43
# 17  for_sale   145000    3     2      0.16
# 18  for_sale   500000    3     3      5.47
# 19  for_sale    32500    3     2      1.05
# 20  for_sale   469200    3     2     26.64
# 21  for_sale    50000    3     2      2.00
# 22  for_sale    15000    3     2      0.25
# 23  for_sale    99000    3     2      0.93
# 24  for_sale  2000000    3     3      2.03
# 25  for_sale  2900000    4     5      0.69
# 26  for_sale  1500000    3     3      0.68
# 27  for_sale    55000    3     2      1.59
# 28  for_sale    25000    3     1      0.50
# 29  for_sale    30000    3     1      0.50
# 30  for_sale    50000    3     2      0.28
# 31  for_sale    75000    3     2      0.11
# 32  for_sale   350000    3     2      0.94
# 33  for_sale   849900    3     3      0.46
# 34  for_sale   849900    3     3      0.46
# 35  for_sale   300000    3     3      0.14
# 36  for_sale   599900    3     2      0.21
# 37  for_sale   100000    3     2     27.50
# 38  for_sale    99000    3     2      0.11
# 39  for_sale    49000    3     3      3.31
# 40  for_sale    49000    3     3      3.47
# 41  for_sale    65000    3     2      0.20
# 42  for_sale    59900    3     2      0.09
# 43  for_sale    99900    3     2      0.20
# 44  for_sale    39900    3     2      0.30
# 45  for_sale    75000    3     2      0.26
# 46  for_sale   399999    3     2      0.12
# 47  for_sale   379000    3     2     42.25
# 48  for_sale   225000    3     2      4.57
# 49  for_sale   450000    3     3      1.96
# 50  for_sale   199900    3     2      6.63
# 51  for_sale    75000    3     2      0.09
# 52  for_sale    75000    3     2      0.23
# 53  for_sale    50000    3     2      0.09
# 54  for_sale   279900    3     3      3.00
# 55  for_sale    99900    3     2      2.99
# 56  for_sale   649900    3     2     24.42
# 57  for_sale   349000    3     2      1.15
# 58  for_sale   899000    3     2      1.88
# 59  for_sale   375000    3     2     16.31
#
#                                          full_address              city  \
# 0   0 0 Bay St /Judson St /Church St, Tiverton, RI...          Tiverton
# 1                  0 52 Range Ave, Taunton, MA, 02780           Taunton
# 2                  0 53 Range Ave, Taunton, MA, 02780           Taunton
# 3            0 A1 Morrison Ave, Middletown, RI, 02842        Middletown
# 4            0 A3 Morrison Ave, Middletown, RI, 02842        Middletown
# 5       0 Abbott Run Valley Rd, Cumberland, RI, 02864        Cumberland
# 6                 0 Adelaide Rd, Glocester, RI, 02859         Glocester
# 7           0 Alton Bradford Rd, Hopkinton, RI, 02894         Hopkinton
# 8            0 Alton Bradford Rd, Richmond, RI, 02833          Richmond
# 9        0 Arrow Head Trl, South Kingstown, RI, 02879   South Kingstown
# 10                   0 Ashmun, Springfield, MA, 01101       Springfield
# 11                 0 Atwells Ave, Johnston, RI, 02919          Johnston
# 12                0 Bayberry Dr, Hopkinton, RI, 02804         Hopkinton
# 13          0 Beacon Hill Rd, Block Island, RI, 02807      Block Island
# 14                0 Benjamin St, Pawtucket, RI, 02861         Pawtucket
# 15  0 Block 3101 Landis Ave Lot 31, Pittsgrove, NJ...        Pittsgrove
# 16             0 Blossom Way, Narragansett, RI, 02882      Narragansett
# 17          0 Boston Neck Rd, Narragansett, RI, 02882      Narragansett
# 18        0 Bridgetown Rd, South Kingstown, RI, 02874   South Kingstown
# 19         0 Broadcove W Lot 52, Waldoboro, ME, 04572         Waldoboro
# 20               0 Broadway St, Woonsocket, RI, 02895        Woonsocket
# 21              0 Bronco Hwy, Burrillville, RI, 02830      Burrillville
# 22            0 Brookside Rd, Narragansett, RI, 02882      Narragansett
# 23         0 Buckeye Brook Rd, Charlestown, RI, 02813       Charlestown
# 24  0 Carnegie Harbor Dr Lot 1, Portsmouth, RI, 02871        Portsmouth
# 25  0 Carnegie Harbor Dr Lot 20, Portsmouth, RI, 0...        Portsmouth
# 26        0 Carnegie Harbor Dr, Portsmouth, RI, 02871        Portsmouth
# 27           0 Centennial St, Burrillville, RI, 02830      Burrillville
# 28              0 Center St Lot 3, Morrill, ME, 04952           Morrill
# 29              0 Center St Lot 4, Morrill, ME, 04952           Morrill
# 30             0 Channing Rd, Narragansett, RI, 02882      Narragansett
# 31                 0 Charlotte Dr, Warwick, RI, 02818           Warwick
# 32               0 Chase Ln Lot 2, Lincoln, RI, 02865           Lincoln
# 33            0 Coletta Ct Lot 1, Cranston, RI, 02921          Cranston
# 34            0 Coletta Ct Lot 2, Cranston, RI, 02921          Cranston
# 35         0 Common Fence Blvd, Portsmouth, RI, 02871        Portsmouth
# 36  0 Curtis Corner Rd Lot 24, South Kingstown, RI...   South Kingstown
# 37                0 Danielson Pike, Foster, RI, 02825            Foster
# 38                  0 Davidson Rd, Warwick, RI, 02886           Warwick
# 39            0 Davis Lot 2, New Braintree, MA, 01531     New Braintree
# 40         0 Davis Rd Lot 3, New Braintree, MA, 01531     New Braintree
# 41                0 Doe Xing, Burrillville, RI, 02859      Burrillville
# 42                   0 Dundas Ave, Warwick, RI, 02889           Warwick
# 43                    0 Eagle St, Johnston, RI, 02919          Johnston
# 44                    0 Echo Rd, Glocester, RI, 02859         Glocester
# 45                    0 Elm St, Woonsocket, RI, 02895        Woonsocket
# 46                   0 Erie St, Woonsocket, RI, 02895        Woonsocket
# 47                   0 Evans Rd, Glocester, RI, 02814         Glocester
# 48           0 Fairfield St Lot A, Oakland, ME, 04963           Oakland
# 49  0 Fairview Ln and Bayside Ave Ln, Portsmouth, ...        Portsmouth
# 50               0 Farnum Pike, Smithfield, RI, 02917        Smithfield
# 51                  0 Foch Ave, Woonsocket, RI, 02895        Woonsocket
# 52            0 Forbes St, East Providence, RI, 02915   East Providence
# 53              0 Forest Hill Dr, Johnston, RI, 02919          Johnston
# 54           0 Gardner Rd, South Kingstown, RI, 02879   South Kingstown
# 55            0 Great Rd, North Smithfield, RI, 02896  North Smithfield
# 56                0 Green Bush Rd, Warwick, RI, 02818           Warwick
# 57         0 Green Meadow Dr, Narragansett, RI, 02882      Narragansett
# 58                 0 Greene Ln, Middletown, RI, 02842        Middletown
# 59              0 Griffin St, Burrillville, RI, 02859      Burrillville
#
#             state  house_size sold_date
# 0    Rhode Island        1450       NaT
# 1   Massachusetts        1859       NaT
# 2   Massachusetts        1859       NaT
# 3    Rhode Island        2500       NaT
# 4    Rhode Island        3120       NaT
# 5    Rhode Island        2600       NaT
# 6    Rhode Island        1236       NaT
# 7    Rhode Island        2060       NaT
# 8    Rhode Island        1500       NaT
# 9    Rhode Island        1808       NaT
# 10  Massachusetts        1690       NaT
# 11   Rhode Island        1434       NaT
# 12   Rhode Island        2060       NaT
# 13   Rhode Island        2200       NaT
# 14   Rhode Island        1752       NaT
# 15     New Jersey        1027       NaT
# 16   Rhode Island        1686       NaT
# 17   Rhode Island        1686       NaT
# 18   Rhode Island        1808       NaT
# 19          Maine        1570       NaT
# 20   Rhode Island        2099       NaT
# 21   Rhode Island        1700       NaT
# 22   Rhode Island        1686       NaT
# 23   Rhode Island        1573       NaT
# 24   Rhode Island        1900       NaT
# 25   Rhode Island        4800       NaT
# 26   Rhode Island        1900       NaT
# 27   Rhode Island        1700       NaT
# 28          Maine        1390       NaT
# 29          Maine        1390       NaT
# 30   Rhode Island        1686       NaT
# 31   Rhode Island        1449       NaT
# 32   Rhode Island        1700       NaT
# 33   Rhode Island        2500       NaT
# 34   Rhode Island        3000       NaT
# 35   Rhode Island        1900       NaT
# 36   Rhode Island        1556       NaT
# 37   Rhode Island        1266       NaT
# 38   Rhode Island        1449       NaT
# 39  Massachusetts        2800       NaT
# 40  Massachusetts        2800       NaT
# 41   Rhode Island        1700       NaT
# 42   Rhode Island        1449       NaT
# 43   Rhode Island        1434       NaT
# 44   Rhode Island        1236       NaT
# 45   Rhode Island        2099       NaT
# 46   Rhode Island        1250       NaT
# 47   Rhode Island        1236       NaT
# 48          Maine        1588       NaT
# 49   Rhode Island        1900       NaT
# 50   Rhode Island        1596       NaT
# 51   Rhode Island        2099       NaT
# 52   Rhode Island        1352       NaT
# 53   Rhode Island        1434       NaT
# 54   Rhode Island        1808       NaT
# 55   Rhode Island        1955       NaT
# 56   Rhode Island        1449       NaT
# 57   Rhode Island        1686       NaT
# 58   Rhode Island        1579       NaT
# 59   Rhode Island        1700       NaT

# %%
df5.tail()
# Out:
#          status    price  bed  bath  acre_lot  \
# 80594  for_sale  1850000    5     4      1.59
# 80595  for_sale  2150000    2     3      0.04
# 80596  for_sale    95000    3     3      0.06
# 80597  for_sale   150000    3     2     50.00
# 80598  for_sale   135000    5     2      0.09
#
#                                             full_address                city  \
# 80594      Zero Bridge St Lot Eight, Hamilton, MA, 01982            Hamilton
# 80595      Zero Worcester Sq Unit TH1, Boston, MA, 02118              Boston
# 80596  Zh-11 Calle 31 Urb Riverview # 501-826608, Bay...             Bayamon
# 80597             Zorn Dr, Middletown Springs, VT, 05757  Middletown Springs
# 80598         Zorzal 84 Bo Cuchillas, Morovis, PR, 00687             Morovis
#
#                state  house_size sold_date
# 80594  Massachusetts        4800       NaT
# 80595  Massachusetts        1514       NaT
# 80596    Puerto Rico         752       NaT
# 80597        Vermont        1716       NaT
# 80598    Puerto Rico        1414       NaT
